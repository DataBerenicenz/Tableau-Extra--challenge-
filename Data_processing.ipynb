# %%
import os, glob
import pandas as pd

# %%
path = "Resources/"

all_files = glob.glob(os.path.join(path,"JC-2020*.csv"))

all_csv = (pd.read_csv(f, sep= ",") for f in all_files)
citi_bike_merged = pd.concat(all_csv, ignore_index= True)

# %%
citi_bike_merged = citi_bike_merged.drop(columns=['bikeid'], axis=1)
citi_bike_merged
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1                143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2                305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3               1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4                277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
# ...              ...                       ...                       ...
# 235751           270  2020-10-13 15:05:35.0860  2020-10-13 15:10:05.3430
# 235752           400  2020-10-13 15:09:03.4890  2020-10-13 15:15:43.9750
# 235753           206  2020-10-13 15:11:34.3500  2020-10-13 15:15:00.5030
# 235754           216  2020-10-13 15:11:49.1510  2020-10-13 15:15:25.6930
# 235755           418  2020-10-13 15:12:31.7920  2020-10-13 15:19:30.5280
#
#         start station id start station name  start station latitude  \
# ...

# %%
citi_bike_merged = citi_bike_merged.sort_values(by=['starttime'])
citi_bike_merged
# Out:
#        tripduration                 starttime                  stoptime  \
# 30086           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 30087          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 30088           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 30089           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 30090           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
# ...             ...                       ...                       ...
# 78696          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 78697          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 78698          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 78699           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 78700          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id          start station name  start station latitude  \
# ...

# %%
conversions= {
    'gender': {
        1: 'Male',
        2: 'Female',
        0: 'Null'
    }}

# %%
citi_bike_merged = citi_bike_merged.copy()
for k,v in conversions.items():
    citi_bike_merged[k] = citi_bike_merged[k].replace(v)

# %%
citi_bike_merged
# Out:
#        tripduration                 starttime                  stoptime  \
# 30086           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 30087          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 30088           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 30089           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 30090           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
# ...             ...                       ...                       ...
# 78696          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 78697          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 78698          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 78699           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 78700          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id          start station name  start station latitude  \
# ...

# %%
citi_bike_merged = citi_bike_merged[citi_bike_merged.gender != 'Null']

# %%
citi_bike_merged
# Out:
#        tripduration                 starttime                  stoptime  \
# 30086           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 30087          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 30088           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 30089           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 30090           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
# ...             ...                       ...                       ...
# 78689           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 78690           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 78694           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
# 78698          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 78700          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id          start station name  start station latitude  \
# ...

# %%
citi_bike_merged.to_csv("citi_bike_merged.csv")
